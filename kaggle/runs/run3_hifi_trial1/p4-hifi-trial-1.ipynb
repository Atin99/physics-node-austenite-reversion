# %%
# Project 4.3 HiFi20 Kaggle single-cell runner.
# Paste this whole file into one Kaggle notebook cell, attach the HiFi20 zip,
# enable GPU, then Commit/Run.

import glob
import os
from pathlib import Path


HIFI20_ENV = {
    # Use the existing runner machinery, but force a higher quality 20h-safe setup.
    "PROJECT43_PROFILE": "balanced",
    "PROJECT43_BASELINE_N_SYNTH": "3500",
    "PROJECT43_STAGE1_EPOCHS": "90",
    "PROJECT43_STAGE2_EPOCHS": "180",
    "PROJECT43_DATA_SYNTH_CALIB": "360",
    "PROJECT43_DATA_SYNTH_EXPLORE": "1200",
    "PROJECT43_DATA_N_TIME_POINTS": "48",
    "PROJECT43_DATA_REAL_WEIGHT": "5.0",
    "PROJECT43_MODEL_BATCH_SIZE": "32",
    "PROJECT43_MODEL_USE_AMP": "1",
    "PROJECT43_MODEL_ADJOINT": "0",
    "PROJECT43_MODEL_USE_SN": "0",
    "PROJECT43_MODEL_RTOL": "2e-4",
    "PROJECT43_MODEL_ATOL": "1e-6",
    "PROJECT43_MODEL_MAX_STEPS": "3000",
    "PROJECT43_MODEL_AUG_DIM": "3",
    "PROJECT43_MODEL_HIDDEN_DIMS": "128,128,96",
    "PROJECT43_ODE_TIME_TRANSFORM": "log10",
    "PROJECT43_ODE_TIME_LOG_SCALE": "6.0",
    "PHYSICSNODE_BATCH_LOG_EVERY": "3",
    "PHYSICSNODE_BATCH_HEARTBEAT_SEC": "30",
}

os.environ.update(HIFI20_ENV)
print("PROJECT 4.3 HIFI20 WRAPPER")
for key in sorted(HIFI20_ENV):
    print(f"{key}={os.environ[key]}")


def find_runner():
    candidates = []
    for pattern in [
        "/kaggle/input/**/project_4_3_bundle/kaggle/notebook_cells/00_RUN_ALL_SINGLE_CELL.py",
        "/kaggle/input/**/project_4_3_hifi20_bundle/kaggle/notebook_cells/00_RUN_ALL_SINGLE_CELL.py",
        "/kaggle/input/**/00_RUN_ALL_SINGLE_CELL.py",
    ]:
        candidates.extend(Path(p) for p in glob.glob(pattern, recursive=True))
    candidates = [p for p in candidates if p.exists()]
    if not candidates:
        raise FileNotFoundError("Attach project_4_3_hifi20_kaggle_input.zip or project_4_3_kaggle_input.zip as a Kaggle dataset.")
    candidates.sort(key=lambda p: (("hifi20" in str(p).lower()), p.stat().st_mtime), reverse=True)
    return candidates[0]


runner = find_runner()
print(f"Executing base runner: {runner}")
code = runner.read_text(encoding="utf-8")
exec(compile(code, str(runner), "exec"), {"__name__": "__main__"})
# Out:
# PROJECT 4.3 HIFI20 WRAPPER
# PHYSICSNODE_BATCH_HEARTBEAT_SEC=30
# PHYSICSNODE_BATCH_LOG_EVERY=3
# PROJECT43_BASELINE_N_SYNTH=3500
# PROJECT43_DATA_N_TIME_POINTS=48
# PROJECT43_DATA_REAL_WEIGHT=5.0
# PROJECT43_DATA_SYNTH_CALIB=360
# PROJECT43_DATA_SYNTH_EXPLORE=1200
# PROJECT43_MODEL_ADJOINT=0
# PROJECT43_MODEL_ATOL=1e-6
# PROJECT43_MODEL_AUG_DIM=3
# PROJECT43_MODEL_BATCH_SIZE=32
# PROJECT43_MODEL_HIDDEN_DIMS=128,128,96
# PROJECT43_MODEL_MAX_STEPS=3000
# PROJECT43_MODEL_RTOL=2e-4
# PROJECT43_MODEL_USE_AMP=1
# PROJECT43_MODEL_USE_SN=0
# PROJECT43_ODE_TIME_LOG_SCALE=6.0
# PROJECT43_ODE_TIME_TRANSFORM=log10
# PROJECT43_PROFILE=balanced
# PROJECT43_STAGE1_EPOCHS=90
# PROJECT43_STAGE2_EPOCHS=180
# Executing base runner: /kaggle/input/datasets/atindatta3/project-4-3-hifi20-kaggle-input-zip/project_4_3_bundle/kaggle/notebook_cells/00_RUN_ALL_SINGLE_CELL.py
# ================================================================================
# PROJECT 4.3 KAGGLE SINGLE-CELL FULL RUN
# ================================================================================
# Started UTC: 2026-05-06T11:06:26.700555+00:00
# Artifact root: /kaggle/working/project_4_3_final_artifacts
# Continue on stage error: True
# Run profile: balanced
# Profile params | baseline_n_synth=3500 | stage1_epochs=90 | stage2_epochs=180
# Model params | batch=32 amp=1 adjoint=0 sn=0 rtol=2e-4 atol=1e-6 max_steps=3000 time=log10
# [time] before 00_setup_extract: elapsed=0.00h
# Installing torchdiffeq ...
# Input bundle already extracted: /kaggle/input/datasets/atindatta3/project-4-3-hifi20-kaggle-input-zip/project_4_3_bundle
# Bundle root: /kaggle/working/project_4_3_bundle/project_4_3_bundle
# Snapshot: /kaggle/working/project_4_3_final_artifacts_snapshot.zip
# [time] before 01_baselines_ml_basic_nn: elapsed=0.00h
#
# ================================================================================
# RUN baseline_all_ml_basic_nn
# CMD: /usr/bin/python3 /kaggle/working/project_4_3_bundle/project_4_3_bundle/scripts/run_project43_pipeline.py --n-synth 3500 --train-with-synth
# CWD: /kaggle/working/project_4_3_bundle/project_4_3_bundle
# ================================================================================
# [runner-heartbeat] baseline_all_ml_basic_nn still running | elapsed=0.5m | no child output for 30s
# {
#   "workspace": "/kaggle/working/project_4_3_bundle/project_4_3_bundle",
#   "split_summary": {
#     "master_rows_all": 409,
#     "experimental_core_exact": 88,
#     "experimental_digitized": 96,
#     "transfer_real_weak_labels": 189,
#     "candidate_or_not_ready": 29,
#     "legacy_unverified": 7,
#     "ml_ready_real_pool": 184,
#     "ml_ready_with_transfer": 373,
#     "ml_ready_strict_nonlegacy": 66,
#     "unique_studies_master": 56,
#     "unique_studies_ml_ready_real": 33
#   },
#   "synthetic_rows_generated": 3500,
#   "synthetic_csv": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/data/synthetic/synthetic_calphad_surrogate.csv",
#   "combined_csv": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/data/processed/ml_ready_with_transfer_plus_synth.csv",
#   "baseline_runs": {
#     "real_only": {
#       "dataset": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/data/processed/ml_ready_real_pool.csv",
#       "rows_used": 184,
#       "studies_used": 33,
#       "predictions_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_only_loso_predictions.csv",
#       "metrics_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_only_metrics.csv",
#       "weights_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_only_fusion_weights.json",
#       "metrics": [
#         {
#           "model": "ols",
#           "rmse": 0.1525963612821175,
#           "mae": 0.12401407407836389,
#           "r2": -0.30184097472037363,
#           "n": 184
#         },
#         {
#           "model": "ridge",
#           "rmse": 0.1517285309165551,
#           "mae": 0.12325677866877265,
#           "r2": -0.28707568748470935,
#           "n": 184
#         },
#         {
#           "model": "knn",
#           "rmse": 0.12984898868406053,
#           "mae": 0.1068724936869815,
#           "r2": 0.057358134857265264,
#           "n": 184
#         },
#         {
#           "model": "basic_nn",
#           "rmse": 0.16719831165528456,
#           "mae": 0.1299493055072374,
#           "r2": -0.5629077917067684,
#           "n": 184
#         },
#         {
#           "model": "fusion",
#           "rmse": 0.13532942859399735,
#           "mae": 0.11112546677389476,
#           "r2": -0.023891828808943805,
#           "n": 184
#         }
#       ]
#     },
#     "real_plus_transfer": {
#       "dataset": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/data/processed/ml_ready_with_transfer.csv",
#       "rows_used": 373,
#       "studies_used": 47,
#       "predictions_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_plus_transfer_loso_predictions.csv",
#       "metrics_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_plus_transfer_metrics.csv",
#       "weights_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_plus_transfer_fusion_weights.json",
#       "metrics": [
#         {
#           "model": "ols",
#           "rmse": 0.1136471226600574,
#           "mae": 0.09204047109455829,
#           "r2": 0.345063843797781,
#           "n": 373
#         },
#         {
#           "model": "ridge",
#           "rmse": 0.11345316774664266,
#           "mae": 0.09194577951679901,
#           "r2": 0.3472974188639456,
#           "n": 373
#         },
#         {
#           "model": "knn",
#           "rmse": 0.112247816356471,
#           "mae": 0.08984869123000694,
#           "r2": 0.3610926570434788,
#           "n": 373
#         },
#         {
#           "model": "basic_nn",
#           "rmse": 0.13829399928927125,
#           "mae": 0.10568206178145029,
#           "r2": 0.030185329528710003,
#           "n": 373
#         },
#         {
#           "model": "fusion",
#           "rmse": 0.10919497440091785,
#           "mae": 0.08659884300641307,
#           "r2": 0.3953732199756893,
#           "n": 373
#         }
#       ]
#     },
#     "real_transfer_synth": {
#       "dataset": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/data/processed/ml_ready_with_transfer_plus_synth.csv",
#       "rows_used": 3873,
#       "studies_used": 48,
#       "predictions_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_transfer_synth_loso_predictions.csv",
#       "metrics_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_transfer_synth_metrics.csv",
#       "weights_file": "/kaggle/working/project_4_3_bundle/project_4_3_bundle/outputs/scenario_real_transfer_synth_fusion_weights.json",
#       "metrics": [
#         {
#           "model": "ols",
#           "rmse": 0.355356811053573,
#           "mae": 0.34117434442633493,
#           "r2": -15.784977102156745,
#           "n": 3873
#         },
#         {
#           "model": "ridge",
#           "rmse": 0.3551280124744671,
#           "mae": 0.3409657446101281,
#           "r2": -15.763369847326835,
#           "n": 3873
#         },
#         {
#           "model": "knn",
#           "rmse": 0.31342446727860723,
#           "mae": 0.3005810635611186,
#           "r2": -12.057416524289737,
#           "n": 3873
#         },
#         {
#           "model": "basic_nn",
#           "rmse": 0.3483846949344908,
#           "mae": 0.3177756407545623,
#           "r2": -15.1327944493549,
#           "n": 3873
#         },
#         {
#           "model": "fusion",
#           "rmse": 0.337629637999193,
#           "mae": 0.32391224122359824,
#           "r2": -14.152091754524518,
#           "n": 3873
#         }
#       ]
#     }
#   }
# }
# Snapshot: /kaggle/working/project_4_3_final_artifacts_snapshot.zip
# [time] before 02_latent_stage1_generate_full: elapsed=0.02h
#
# ================================================================================
# RUN latent_stage1_full_generate_data
# CMD: /usr/bin/python3 /kaggle/working/project43_latent_stage1_full/src/main.py --generate-data --device cuda
# CWD: /kaggle/working/project43_latent_stage1_full/src
# ================================================================================
# 11:07:36 [INFO] Device: cuda | Adjoint: False | AMP: True
# 11:07:36 [INFO] Config: solver=dopri5 rtol=0.0002 atol=1e-06 max_steps=3000 batch=32 n_time=48 synth_cal=360 synth_exp=1200 hidden=[128, 128, 96] aug=3 sn=False time=log10
# 11:07:36 [INFO] STEP 1: Generate Data (3-Tier: Real -> Calibrated -> Exploratory)
# 11:07:36 [INFO] NumExpr defaulting to 4 threads.
# 11:07:37 [INFO] ======================================================================
# EXPERIMENTAL DATA SUMMARY
# ======================================================================
#
#   [gibbs_2011] Fe-7.1Mn-0.1C
#     Source: Metallurgical and Materials Transactions A (2011)
#     DOI: 10.1007/s11661-011-0736-2
#     Initial: cold-rolled, 50% reduction
#     Data: 5 points | T: 575-675°C | Quality: {'table'}
#
#   [luo_2011] Fe-5.0Mn-0.2C
#     Source: Acta Materialia (2011)
#     DOI: 10.1016/j.actamat.2011.03.025
#     Initial: cold-rolled martensitic
#     Data: 7 points | T: 650-650°C | Quality: {'text_reported', 'digitized_figure'}
#
#   [pmc11053108_2024] Fe-4.7Mn-0.16C-1.6Al-0.2Si-0.2Mo
#     Source: Open Access (PMC) (2024)
#     DOI: PMC11053108
#     Initial: cold-rolled
#     Data: 7 points | T: 640-1000°C | Quality: {'text_reported'}
#
#   [pmc11173901_2024] Fe-9.4Mn-0.2C-4.3Al
#     Source: Open Access (PMC) (2024)
#     DOI: PMC11173901
#     Initial: not specified
#     Data: 3 points | T: 750-850°C | Quality: {'digitized_figure'}
#
#   [pmc6266817_2018] Fe-5.0Mn-0.12C-1.0Al-0.2Mo-0.05Nb
#     Source: Open Access (PMC) (2018)
#     DOI: PMC6266817
#     Initial: cold-rolled (CR)
#     Data: 6 points | T: 600-750°C | Quality: {'text_reported', 'digitized_figure'}
#
#   [pmc6266817_2018_HR] Fe-5.0Mn-0.12C-1.0Al-0.2Mo-0.05Nb
#     Source: Open Access (PMC) (2018)
#     DOI: PMC6266817
#     Initial: hot-rolled (HR)
#     Data: 4 points | T: 600-690°C | Quality: {'text_reported', 'digitized_figure'}
#
#   [yan_2022] Fe-6.0Mn-0.15C-1.5Al-0.3Si
#     Source: MDPI Metals / EBSD study (2022)
#     DOI: yan_2022_EBSD
#     Initial: cold-rolled
#     Data: 3 points | T: 650-710°C | Quality: {'text_reported'}
#
#   [aliabad_2026] Fe-6.0Mn-0.4C-2.0Al-1.0Si
#     Source: Open Access (2026)
#     DOI: aliabad_2026
#     Initial: not specified
#     Data: 2 points | T: 680-680°C | Quality: {'text_reported'}
#
#   [frontiers_2020] Fe-8.0Mn-0.2C-3.0Al
#     Source: Frontiers in Materials (2020)
#     DOI: frontiers_2020
#     Initial: not specified
#     Data: 2 points | T: 680-680°C | Quality: {'text_reported'}
#
#   [lpbf_2021] Fe-3.93Mn-0.23C-2.01Al-0.51Si
#     Source: Materials (MDPI) (2021)
#     DOI: MDPI_Materials_14_3081
#     Initial: LPBF as-built
#     Data: 3 points | T: 25-750°C | Quality: {'text_reported'}
#
#   [demoor_2011] Fe-7.1Mn-0.11C
#     Source: Scripta Materialia (2011)
#     DOI: 10.1016/j.scriptamat.2010.09.040
#     Initial: cold-rolled martensitic
#     Data: 5 points | T: 600-600°C | Quality: {'digitized_figure'}
#
#   [lee_decooman_2014] Fe-5.8Mn-0.12C-2.0Al
#     Source: Metallurgical and Materials Transactions A (2013)
#     DOI: 10.1007/s11661-013-1860-y
#     Initial: cold-rolled martensitic
#     Data: 6 points | T: 625-750°C | Quality: {'digitized_figure'}
#
#   [nakada_2014] Fe-6.0Mn
#     Source: Acta Materialia (2014)
#     DOI: 10.1016/j.actamat.2013.10.067
#     Initial: quenched martensite
#     Data: 7 points | T: 500-675°C | Quality: {'digitized_figure'}
#
#   [shi_2010] Fe-5.0Mn-0.2C
#     Source: Scripta Materialia (2010)
#     DOI: 10.1016/j.scriptamat.2010.06.023
#     Initial: cold-rolled martensitic
#     Data: 5 points | T: 620-680°C | Quality: {'digitized_figure'}
#
#   [arlazarov_2012] Fe-5.0Mn-0.1C
#     Source: Materials Science and Engineering: A (2012)
#     DOI: 10.1016/j.msea.2012.02.024
#     Initial: cold-rolled, double annealed
#     Data: 5 points | T: 600-700°C | Quality: {'digitized_figure'}
#
#   [han_2014] Fe-9.0Mn-0.05C
#     Source: Materials Science and Engineering: A (2014)
#     DOI: 10.1016/j.msea.2015.02.055
#     Initial: water-quenched martensite
#     Data: 6 points | T: 600-725°C | Quality: {'digitized_figure'}
#
#   [miller_2013] Fe-5.8Mn-0.1C-0.5Si
#     Source: Metallurgical Transactions (2013)
#     DOI: 10.1007/BF02647665
#     Initial: cold-rolled and annealed
#     Data: 5 points | T: 600-700°C | Quality: {'digitized_figure'}
#
#   [hu_luo_2017] Fe-7.0Mn-0.1C-0.5Al
#     Source: Journal of Alloys and Compounds (2017)
#     DOI: 10.1016/j.jallcom.2017.07.174
#     Initial: warm-rolled
#     Data: 4 points | T: 600-675°C | Quality: {'digitized_figure'}
#
#   [cai_2016] Fe-10.0Mn-0.3C-2.0Al
#     Source: Acta Materialia (2015)
#     DOI: 10.1016/j.actamat.2014.10.052
#     Initial: cold-rolled martensitic
#     Data: 4 points | T: 625-700°C | Quality: {'digitized_figure'}
#
#   [zhao_2014] Fe-7.9Mn-0.07C-0.05Al-0.14Si
#     Source: Materials (2014)
#     DOI: 10.3390/ma7127891
#     Initial: cold-rolled martensitic
#     Data: 7 points | T: 580-700°C | Quality: {'digitized_figure'}
#
#   [suh_2017] Fe-6.0Mn-0.1C-3.0Al
#     Source: Scripta Materialia (2017)
#     DOI: 10.1016/j.scriptamat.2016.07.013
#     Initial: cold-rolled martensitic
#     Data: 5 points | T: 700-800°C | Quality: {'digitized_figure'}
#
#   [sun_2018] Fe-12.0Mn-0.05C
#     Source: Acta Materialia (2018)
#     DOI: 10.1016/j.actamat.2018.02.005
#     Initial: cold-rolled martensitic
#     Data: 8 points | T: 575-675°C | Quality: {'digitized_figure'}
#
#   [ma_2019] Fe-8.0Mn-0.2C-2.0Al-0.5Si
#     Source: Materials (2019)
#     DOI: 10.3390/ma12091402
#     Initial: cold-rolled martensitic
#     Data: 6 points | T: 625-750°C | Quality: {'digitized_figure'}
#
#   [demoor_2015] Fe-7.0Mn-0.1C
#     Source: ISIJ International (2015)
#     DOI: 10.2355/isijinternational.55.234
#     Initial: cold-rolled martensitic
#     Data: 6 points | T: 620-620°C | Quality: {'digitized_figure'}
#
#   [hausman_2017] Fe-6.0Mn-0.3C-0.5Si
#     Source: Materials Science and Engineering: A (2017)
#     DOI: 10.1016/j.msea.2016.12.055
#     Initial: cold-rolled martensitic
#     Data: 4 points | T: 575-650°C | Quality: {'digitized_figure'}
#
# ======================================================================
# TOTAL: 125 experimental data points from 25 studies
# ======================================================================
# 11:07:37 [INFO] Loaded 125 experimental data points from 25 studies
# 11:07:37 [INFO] No user CSV files found in /kaggle/working/project43_latent_stage1_full/src/data/user_experimental
# 11:07:37 [INFO] Converted 125 real measurements into 105 training curves (227 total points)
# 11:07:37 [INFO] TIER 1 (Real): 105 curves, 227 points
# 11:07:38 [INFO] Generated 360 calibrated synthetic curves (17280 points) | provenance='synthetic_calibrated'
# 11:07:38 [INFO] TIER 2 (Calibrated Synthetic): 360 curves, 17280 points
# 11:07:40 [INFO] Generated 1200 exploratory synthetic curves (57600 points) | provenance='synthetic_exploratory'
# 11:07:40 [INFO] TIER 3 (Exploratory Synthetic): 1200 curves, 57600 points
# 11:07:40 [INFO]
# ============================================================
# 11:07:40 [INFO] FULL DATASET: 1665 curves, 75107 total points
# 11:07:40 [INFO]   synthetic_exploratory: 57600 points
# 11:07:40 [INFO]   synthetic_calibrated: 17280 points
# 11:07:40 [INFO]   experimental: 227 points
# 11:07:40 [INFO] ============================================================
#
# 11:07:43 [INFO] Loaded 125 experimental data points from 25 studies
# 11:07:43 [INFO] Saved 125 real experimental points to /kaggle/working/project43_latent_stage1_full/src/data/literature_validation/literature_validation.csv
# 11:07:44 [INFO] Saved data overview figure to /kaggle/working/project43_latent_stage1_full/src/figures/data_overview.png
# 11:07:44 [INFO]   synthetic_exploratory: 57600 data points
# 11:07:44 [INFO]   synthetic_calibrated: 17280 data points
# 11:07:44 [INFO]   experimental: 227 data points
# 11:07:44 [INFO] Generated 75107 total data points (1665 curves) | train=1165 val=250 test=250
# 11:07:44 [INFO] Pipeline done in 0.1m
# Snapshot: /kaggle/working/project_4_3_final_artifacts_snapshot.zip
# [time] before 03_latent_stage1_train_90ep: elapsed=0.02h
#
# ================================================================================
# RUN latent_stage1_full_train_90ep
# CMD: /usr/bin/python3 /kaggle/working/project43_latent_stage1_full/src/main.py --train --epochs 90 --device cuda --resume-last
# CWD: /kaggle/working/project43_latent_stage1_full/src
# ================================================================================
# 11:07:50 [INFO] Device: cuda | Adjoint: False | AMP: True
# 11:07:50 [INFO] Config: solver=dopri5 rtol=0.0002 atol=1e-06 max_steps=3000 batch=32 n_time=48 synth_cal=360 synth_exp=1200 hidden=[128, 128, 96] aug=3 sn=False time=log10
# 11:07:50 [INFO] STEP 2: Train PhysicsNODE
# 11:07:50 [INFO] NumExpr defaulting to 4 threads.
# 11:07:51 [INFO] PhysicsNODE | Params: 67,337 (67,337 trainable) | Latent: 32 | Aug: 3 | Adjoint: False
# 11:07:59 [INFO] ============================================================
# 11:07:59 [INFO] Training on cuda | Epochs: 90 | Batch: 32 | LR: 0.0003
# 11:07:59 [INFO] AMP: True | Adjoint: False | SWAG: False
# 11:07:59 [INFO] ODE time transform: log10 | scale: 6.0
# 11:07:59 [INFO] Checkpoint metric: val_real_rmse
# 11:07:59 [INFO] Train batches: 37 | Val batches: 8
# 11:07:59 [INFO] Batch heartbeat: every 3 batches
# 11:07:59 [INFO] ============================================================
# 11:07:59 [INFO] E0001 batch 0001/0037 start
# 11:08:04 [INFO] E0001 batch 0001/0037 done | avg_total=0.00307 avg_data=0.00098 avg_nfe=718 skipped=0 elapsed=0.1m
# 11:08:08 [INFO] E0001 batch 0003/0037 start
# 11:08:12 [INFO] E0001 batch 0003/0037 done | avg_total=0.00373 avg_data=0.00118 avg_nfe=706 skipped=0 elapsed=0.2m
# 11:08:19 [INFO] E0001 batch 0006/0037 start
# 11:08:22 [INFO] E0001 batch 0006/0037 done | avg_total=0.00378 avg_data=0.00118 avg_nfe=689 skipped=0 elapsed=0.4m
# 11:08:29 [INFO] E0001 batch 0008/0037 running | batch_elapsed=2.8s epoch_elapsed=0.5m
# 11:08:30 [INFO] E0001 batch 0009/0037 start
# 11:08:34 [INFO] E0001 batch 0009/0037 done | avg_total=0.00340 avg_data=0.00109 avg_nfe=697 skipped=0 elapsed=0.6m
# 11:08:41 [INFO] E0001 batch 0012/0037 start
# 11:08:44 [INFO] E0001 batch 0012/0037 done | avg_total=0.00381 avg_data=0.00117 avg_nfe=698 skipped=0 elapsed=0.8m
# 11:08:52 [INFO] E0001 batch 0015/0037 start
# 11:08:55 [INFO] E0001 batch 0015/0037 done | avg_total=0.00371 avg_data=0.00115 avg_nfe=698 skipped=0 elapsed=0.9m
# 11:08:59 [INFO] E0001 batch 0016/0037 running | batch_elapsed=3.5s epoch_elapsed=1.0m
# 11:09:03 [INFO] E0001 batch 0018/0037 start
# 11:09:06 [INFO] E0001 batch 0018/0037 done | avg_total=0.00404 avg_data=0.00121 avg_nfe=701 skipped=0 elapsed=1.1m
# 11:09:14 [INFO] E0001 batch 0021/0037 start
# 11:09:18 [INFO] E0001 batch 0021/0037 done | avg_total=0.00411 avg_data=0.00124 avg_nfe=706 skipped=0 elapsed=1.3m
# 11:09:25 [INFO] E0001 batch 0024/0037 start
# 11:09:29 [INFO] E0001 batch 0024/0037 running | batch_elapsed=3.5s epoch_elapsed=1.5m
# 11:09:29 [INFO] E0001 batch 0024/0037 done | avg_total=0.00404 avg_data=0.00123 avg_nfe=709 skipped=0 elapsed=1.5m
# 11:09:37 [INFO] E0001 batch 0027/0037 start
# 11:09:40 [INFO] E0001 batch 0027/0037 done | avg_total=0.00438 avg_data=0.00130 avg_nfe=713 skipped=0 elapsed=1.7m
# 11:09:48 [INFO] E0001 batch 0030/0037 start
# 11:09:52 [INFO] E0001 batch 0030/0037 done | avg_total=0.00431 avg_data=0.00128 avg_nfe=716 skipped=0 elapsed=1.9m
# 11:09:59 [INFO] E0001 batch 0032/0037 running | batch_elapsed=3.0s epoch_elapsed=2.0m
# 11:10:00 [INFO] E0001 batch 0033/0037 start
# 11:10:03 [INFO] E0001 batch 0033/0037 done | avg_total=0.00437 avg_data=0.00130 avg_nfe=719 skipped=0 elapsed=2.1m
# 11:10:12 [INFO] E0001 batch 0036/0037 start
# 11:10:16 [INFO] E0001 batch 0036/0037 done | avg_total=0.00425 avg_data=0.00127 avg_nfe=728 skipped=0 elapsed=2.3m
# 11:10:18 [INFO] E0001 batch 0037/0037 done | avg_total=0.00424 avg_data=0.00127 avg_nfe=716 skipped=0 elapsed=2.3m
# 11:10:29 [INFO] E   1 | T:0.00424 V:0.00037 | RMSE:0.02498 RealRMSE:0.28837 | End:0.02727 RealEnd:0.26626 | NFE:716 | Viol:0.00% | Skip:0 | LR:3.0e-04
# 11:10:29 [INFO] E0002 batch 0001/0037 start
# 11:10:33 [INFO] E0002 batch 0001/0037 done | avg_total=0.00177 avg_data=0.00079 avg_nfe=814 skipped=0 elapsed=0.1m
# 11:10:37 [INFO] E0002 batch 0003/0037 start
# 11:10:42 [INFO] E0002 batch 0003/0037 done | avg_total=0.00185 avg_data=0.00076 avg_nfe=808 skipped=0 elapsed=0.2m
# 11:10:50 [INFO] E0002 batch 0006/0037 start
# 11:10:54 [INFO] E0002 batch 0006/0037 done | avg_total=0.00338 avg_data=0.00111 avg_nfe=827 skipped=0 elapsed=0.4m
# 11:10:59 [INFO] E0002 batch 0008/0037 running | batch_elapsed=0.8s epoch_elapsed=0.5m
# 11:11:02 [INFO] E0002 batch 0009/0037 start
# 11:11:07 [INFO] E0002 batch 0009/0037 done | avg_total=0.00376 avg_data=0.00118 avg_nfe=825 skipped=0 elapsed=0.6m
# 11:11:15 [INFO] E0002 batch 0012/0037 start
# 11:11:19 [INFO] E0002 batch 0012/0037 done | avg_total=0.00391 avg_data=0.00120 avg_nfe=818 skipped=0 elapsed=0.8m
# 11:11:27 [INFO] E0002 batch 0015/0037 start
# 11:11:29 [INFO] E0002 batch 0015/0037 running | batch_elapsed=2.4s epoch_elapsed=1.0m
# 11:11:30 [INFO] E0002 batch 0015/0037 done | avg_total=0.00391 avg_data=0.00120 avg_nfe=812 skipped=0 elapsed=1.0m
# 11:11:38 [INFO] E0002 batch 0018/0037 start
# 11:11:42 [INFO] E0002 batch 0018/0037 done | avg_total=0.00447 avg_data=0.00131 avg_nfe=806 skipped=0 elapsed=1.2m
# 11:11:50 [INFO] E0002 batch 0021/0037 start
# 11:11:55 [INFO] E0002 batch 0021/0037 done | avg_total=0.00451 avg_data=0.00133 avg_nfe=816 skipped=0 elapsed=1.4m
# 11:11:59 [INFO] E0002 batch 0022/0037 running | batch_elapsed=4.1s epoch_elapsed=1.5m
# 11:12:04 [INFO] E0002 batch 0024/0037 start
# 11:12:08 [INFO] E0002 batch 0024/0037 done | avg_total=0.00470 avg_data=0.00136 avg_nfe=825 skipped=0 elapsed=1.7m
# 11:12:16 [INFO] E0002 batch 0027/0037 start
# 11:12:20 [INFO] E0002 batch 0027/0037 done | avg_total=0.00481 avg_data=0.00139 avg_nfe=821 skipped=0 elapsed=1.9m
# 11:12:28 [INFO] E0002 batch 0030/0037 start
# 11:12:29 [INFO] E0002 batch 0030/0037 running | batch_elapsed=0.9s epoch_elapsed=2.0m
# 11:12:32 [INFO] E0002 batch 0030/0037 done | avg_total=0.00473 avg_data=0.00137 avg_nfe=817 skipped=0 elapsed=2.0m
# 11:12:40 [INFO] E0002 batch 0033/0037 start
# 11:12:44 [INFO] E0002 batch 0033/0037 done | avg_total=0.00468 avg_data=0.00136 avg_nfe=814 skipped=0 elapsed=2.2m
# 11:12:52 [INFO] E0002 batch 0036/0037 start
# 11:12:56 [INFO] E0002 batch 0036/0037 done | avg_total=0.00469 avg_data=0.00136 avg_nfe=812 skipped=0 elapsed=2.4m
# 11:12:57 [INFO] E0002 batch 0037/0037 done | avg_total=0.00464 avg_data=0.00135 avg_nfe=798 skipped=0 elapsed=2.5m
# 11:13:09 [INFO] E   2 | T:0.00464 V:0.00036 | RMSE:0.02469 RealRMSE:0.28663 | End:0.02721 RealEnd:0.26462 | NFE:798 | Viol:0.00% | Skip:0 | LR:3.0e-04
# 11:13:09 [INFO] E0003 batch 0001/0037 start
# 11:13:12 [INFO] E0003 batch 0001/0037 done | avg_total=0.01245 avg_data=0.00280 avg_nfe=766 skipped=0 elapsed=0.1m
# 11:13:16 [INFO] E0003 batch 0003/0037 start
# 11:13:19 [INFO] E0003 batch 0003/0037 done | avg_total=0.00783 avg_data=0.00193 avg_nfe=768 skipped=0 elapsed=0.2m
# 11:13:27 [INFO] E0003 batch 0006/0037 start
# 11:13:30 [INFO] E0003 batch 0006/0037 done | avg_total=0.00628 avg_data=0.00166 avg_nfe=771 skipped=0 elapsed=0.4m
# 11:13:38 [INFO] E0003 batch 0009/0037 start
# 11:13:39 [INFO] E0003 batch 0009/0037 running | batch_elapsed=0.6s epoch_elapsed=0.5m
# 11:13:42 [INFO] E0003 batch 0009/0037 done | avg_total=0.00537 avg_data=0.00148 avg_nfe=769 skipped=0 elapsed=0.6m
# 11:13:49 [INFO] E0003 batch 0012/0037 start
# 11:13:53 [INFO] E0003 batch 0012/0037 done | avg_total=0.00519 avg_data=0.00147 avg_nfe=771 skipped=0 elapsed=0.7m
# 11:14:01 [INFO] E0003 batch 0015/0037 start
# 11:14:04 [INFO] E0003 batch 0015/0037 done | avg_total=0.00497 avg_data=0.00142 avg_nfe=770 skipped=0 elapsed=0.9m
# 11:14:09 [INFO] E0003 batch 0017/0037 running | batch_elapsed=0.7s epoch_elapsed=1.0m
# 11:14:12 [INFO] E0003 batch 0018/0037 start
# 11:14:16 [INFO] E0003 batch 0018/0037 done | avg_total=0.00462 avg_data=0.00134 avg_nfe=768 skipped=0 elapsed=1.1m
# 11:14:23 [INFO] E0003 batch 0021/0037 start
# 11:14:27 [INFO] E0003 batch 0021/0037 done | avg_total=0.00469 avg_data=0.00136 avg_nfe=766 skipped=0 elapsed=1.3m
# 11:14:34 [INFO] E0003 batch 0024/0037 start
# 11:14:38 [INFO] E0003 batch 0024/0037 done | avg_total=0.00462 avg_data=0.00134 avg_nfe=768 skipped=0 elapsed=1.5m
# 11:14:39 [INFO] E0003 batch 0025/0037 running | batch_elapsed=0.4s epoch_elapsed=1.5m
# 11:14:46 [INFO] E0003 batch 0027/0037 start
# 11:14:50 [INFO] E0003 batch 0027/0037 done | avg_total=0.00450 avg_data=0.00131 avg_nfe=768 skipped=0 elapsed=1.7m
# 11:14:57 [INFO] E0003 batch 0030/0037 start
# 11:15:01 [INFO] E0003 batch 0030/0037 done | avg_total=0.00436 avg_data=0.00129 avg_nfe=769 skipped=0 elapsed=1.9m
# 11:15:09 [INFO] E0003 batch 0032/0037 running | batch_elapsed=3.8s epoch_elapsed=2.0m
# 11:15:09 [INFO] E0003 batch 0033/0037 start
# 11:15:13 [INFO] E0003 batch 0033/0037 done | avg_total=0.00436 avg_data=0.00129 avg_nfe=771 skipped=0 elapsed=2.1m
# 11:15:20 [INFO] E0003 batch 0036/0037 start
# 11:15:24 [INFO] E0003 batch 0036/0037 done | avg_total=0.00432 avg_data=0.00128 avg_nfe=771 skipped=0 elapsed=2.3m
# 11:15:25 [INFO] E0003 batch 0037/0037 done | avg_total=0.00452 avg_data=0.00131 avg_nfe=759 skipped=0 elapsed=2.3m
# 11:15:37 [INFO] E   3 | T:0.00452 V:0.00035 | RMSE:0.02444 RealRMSE:0.28480 | End:0.02721 RealEnd:0.26292 | NFE:759 | Viol:0.00% | Skip:0 | LR:3.0e-04
# 11:15:37 [INFO] E0004 batch 0001/0037 start
# 11:15:41 [INFO] E0004 batch 0001/0037 done | avg_total=0.00329 avg_data=0.00106 avg_nfe=784 skipped=0 elapsed=0.1m
# 11:15:44 [INFO] E0004 batch 0003/0037 start
# 11:15:48 [INFO] E0004 batch 0003/0037 done | avg_total=0.00312 avg_data=0.00101 avg_nfe=778 skipped=0 elapsed=0.2m
# 11:15:55 [INFO] E0004 batch 0006/0037 start
# 11:15:59 [INFO] E0004 batch 0006/0037 done | avg_total=0.00434 avg_data=0.00127 avg_nfe=778 skipped=0 elapsed=0.4m
# 11:16:06 [INFO] E0004 batch 0009/0037 start
# 11:16:07 [INFO] E0004 batch 0009/0037 running | batch_elapsed=0.5s epoch_elapsed=0.5m
# 11:16:10 [INFO] E0004 batch 0009/0037 done | avg_total=0.00398 avg_data=0.00120 avg_nfe=775 skipped=0 elapsed=0.6m
# 11:16:17 [INFO] E0004 batch 0012/0037 start
# 11:16:21 [INFO] E0004 batch 0012/0037 done | avg_total=0.00428 avg_data=0.00125 avg_nfe=774 skipped=0 elapsed=0.7m
# 11:16:28 [INFO] E0004 batch 0015/0037 start
# 11:16:32 [INFO] E0004 batch 0015/0037 done | avg_total=0.00430 avg_data=0.00126 avg_nfe=773 skipped=0 elapsed=0.9m
# 11:16:37 [INFO] E0004 batch 0017/0037 running | batch_elapsed=0.6s epoch_elapsed=1.0m
# 11:16:40 [INFO] E0004 batch 0018/0037 start
# 11:16:44 [INFO] E0004 batch 0018/0037 done | avg_total=0.00424 avg_data=0.00125 avg_nfe=771 skipped=0 elapsed=1.1m
# 11:16:51 [INFO] E0004 batch 0021/0037 start
# 11:16:55 [INFO] E0004 batch 0021/0037 done | avg_total=0.00461 avg_data=0.00132 avg_nfe=773 skipped=0 elapsed=1.3m
# 11:17:02 [INFO] E0004 batch 0024/0037 start
# 11:17:06 [INFO] E0004 batch 0024/0037 done | avg_total=0.00480 avg_data=0.00136 avg_nfe=777 skipped=0 elapsed=1.5m
# 11:17:07 [INFO] E0004 batch 0025/0037 running | batch_elapsed=0.5s epoch_elapsed=1.5m
# 11:17:14 [INFO] E0004 batch 0027/0037 start
# 11:17:18 [INFO] E0004 batch 0027/0037 done | avg_total=0.00459 avg_data=0.00132 avg_nfe=778 skipped=0 elapsed=1.7m
# 11:17:26 [INFO] E0004 batch 0030/0037 start
# 11:17:29 [INFO] E0004 batch 0030/0037 done | avg_total=0.00446 avg_data=0.00129 avg_nfe=779 skipped=0 elapsed=1.9m
# 11:17:37 [INFO] E0004 batch 0032/0037 running | batch_elapsed=3.7s epoch_elapsed=2.0m
# 11:17:37 [INFO] E0004 batch 0033/0037 start
# 11:17:41 [INFO] E0004 batch 0033/0037 done | avg_total=0.00449 avg_data=0.00130 avg_nfe=781 skipped=0 elapsed=2.1m
# 11:17:49 [INFO] E0004 batch 0036/0037 start
# 11:17:53 [INFO] E0004 batch 0036/0037 done | avg_total=0.00440 avg_data=0.00129 avg_nfe=784 skipped=0 elapsed=2.3m
# 11:17:54 [INFO] E0004 batch 0037/0037 done | avg_total=0.00433 avg_data=0.00128 avg_nfe=772 skipped=0 elapsed=2.3m
# 11:18:05 [INFO] E   4 | T:0.00433 V:0.00034 | RMSE:0.02413 RealRMSE:0.28149 | End:0.02739 RealEnd:0.25990 | NFE:772 | Viol:0.00% | Skip:0 | LR:3.0e-04
# 11:18:05 [INFO] E0005 batch 0001/0037 start
# 11:18:09 [INFO] E0005 batch 0001/0037 done | avg_total=0.00519 avg_data=0.00143 avg_nfe=820 skipped=0 elapsed=0.1m
# 11:18:13 [INFO] E0005 batch 0003/0037 start
# 11:18:17 [INFO] E0005 batch 0003/0037 done | avg_total=0.00450 avg_data=0.00129 avg_nfe=834 skipped=0 elapsed=0.2m
# 11:18:25 [INFO] E0005 batch 0006/0037 start
# 11:18:29 [INFO] E0005 batch 0006/0037 done | avg_total=0.00521 avg_data=0.00143 avg_nfe=835 skipped=0 elapsed=0.4m
# 11:18:35 [INFO] E0005 batch 0008/0037 running | batch_elapsed=2.3s epoch_elapsed=0.5m
# 11:18:38 [INFO] E0005 batch 0009/0037 start
# 11:18:42 [INFO] E0005 batch 0009/0037 done | avg_total=0.00556 avg_data=0.00154 avg_nfe=873 skipped=0 elapsed=0.6m
# 11:18:51 [INFO] E0005 batch 0012/0037 start
# 11:18:56 [INFO] E0005 batch 0012/0037 done | avg_total=0.00538 avg_data=0.00149 avg_nfe=896 skipped=0 elapsed=0.8m
# 11:19:04 [INFO] E0005 batch 0015/0037 start
# 11:19:05 [INFO] E0005 batch 0015/0037 running | batch_elapsed=1.4s epoch_elapsed=1.0m
# 11:19:08 [INFO] E0005 batch 0015/0037 done | avg_total=0.00538 avg_data=0.00148 avg_nfe=897 skipped=0 elapsed=1.0m
# 11:19:16 [INFO] E0005 batch 0018/0037 start
# 11:19:20 [INFO] E0005 batch 0018/0037 done | avg_total=0.00517 avg_data=0.00143 avg_nfe=886 skipped=0 elapsed=1.2m
# 11:19:28 [INFO] E0005 batch 0021/0037 start
# 11:19:32 [INFO] E0005 batch 0021/0037 done | avg_total=0.00532 avg_data=0.00146 avg_nfe=878 skipped=0 elapsed=1.4m
# 11:19:35 [INFO] E0005 batch 0022/0037 running | batch_elapsed=3.7s epoch_elapsed=1.5m
# 11:19:40 [INFO] E0005 batch 0024/0037 start
# 11:19:44 [INFO] E0005 batch 0024/0037 done | avg_total=0.00506 avg_data=0.00141 avg_nfe=869 skipped=0 elapsed=1.6m
# 11:19:51 [INFO] E0005 batch 0027/0037 start
# 11:19:55 [INFO] E0005 batch 0027/0037 done | avg_total=0.00503 avg_data=0.00140 avg_nfe=863 skipped=0 elapsed=1.8m
# 11:20:03 [INFO] E0005 batch 0030/0037 start
# 11:20:05 [INFO] E0005 batch 0030/0037 running | batch_elapsed=2.1s epoch_elapsed=2.0m
# 11:20:07 [INFO] E0005 batch 0030/0037 done | avg_total=0.00478 avg_data=0.00135 avg_nfe=857 skipped=0 elapsed=2.0m
# 11:20:15 [INFO] E0005 batch 0033/0037 start
# 11:20:19 [INFO] E0005 batch 0033/0037 done | avg_total=0.00482 avg_data=0.00135 avg_nfe=851 skipped=0 elapsed=2.2m
# 11:20:26 [INFO] E0005 batch 0036/0037 start
# 11:20:30 [INFO] E0005 batch 0036/0037 done | avg_total=0.00481 avg_data=0.00135 avg_nfe=847 skipped=0 elapsed=2.4m
# 11:20:32 [INFO] E0005 batch 0037/0037 done | avg_total=0.00471 avg_data=0.00132 avg_nfe=832 skipped=0 elapsed=2.4m
# 11:20:44 [INFO] E   5 | T:0.00471 V:0.00034 | RMSE:0.02383 RealRMSE:0.27427 | End:0.02872 RealEnd:0.25343 | NFE:832 | Viol:0.00% | Skip:0 | LR:3.0e-04
# 11:20:44 [INFO] E0006 batch 0001/0037 start
# 11:20:47 [INFO] E0006 batch 0001/0037 done | avg_total=0.00201 avg_data=0.00073 avg_nfe=790 skipped=0 elapsed=0.1m
# 11:20:51 [INFO] E0006 batch 0003/0037 start
# 11:20:55 [INFO] E0006 batch 0003/0037 done | avg_total=0.00264 avg_data=0.00089 avg_nfe=796 skipped=0 elapsed=0.2m
# 11:21:03 [INFO] E0006 batch 0006/0037 start
# 11:21:07 [INFO] E0006 batch 0006/0037 done | avg_total=0.00312 avg_data=0.00099 avg_nfe=810 skipped=0 elapsed=0.4m
# 11:21:14 [INFO] E0006 batch 0008/0037 running | batch_elapsed=2.4s epoch_elapsed=0.5m
# 11:21:15 [INFO] E0006 batch 0009/0037 start
# 11:21:19 [INFO] E0006 batch 0009/0037 done | avg_total=0.00424 avg_data=0.00121 avg_nfe=827 skipped=0 elapsed=0.6m
# 11:21:28 [INFO] E0006 batch 0012/0037 start
# 11:21:32 [INFO] E0006 batch 0012/0037 done | avg_total=0.00458 avg_data=0.00128 avg_nfe=832 skipped=0 elapsed=0.8m
# 11:21:40 [INFO] E0006 batch 0015/0037 start
# 11:21:44 [INFO] E0006 batch 0015/0037 done | avg_total=0.00503 avg_data=0.00136 avg_nfe=834 skipped=0 elapsed=1.0m
# 11:21:44 [INFO] E0006 batch 0016/0037 running | batch_elapsed=0.1s epoch_elapsed=1.0m
# 11:21:51 [INFO] E0006 batch 0018/0037 start
# 11:21:56 [INFO] E0006 batch 0018/0037 done | avg_total=0.00478 avg_data=0.00132 avg_nfe=832 skipped=0 elapsed=1.2m
# 11:22:04 [INFO] E0006 batch 0021/0037 start
# 11:22:08 [INFO] E0006 batch 0021/0037 done | avg_total=0.00469 avg_data=0.00130 avg_nfe=832 skipped=0 elapsed=1.4m
# 11:22:14 [INFO] E0006 batch 0023/0037 running | batch_elapsed=2.1s epoch_elapsed=1.5m
# 11:22:16 [INFO] E0006 batch 0024/0037 start
# 11:22:20 [INFO] E0006 batch 0024/0037 done | avg_total=0.00447 avg_data=0.00125 avg_nfe=830 skipped=0 elapsed=1.6m
# 11:22:28 [INFO] E0006 batch 0027/0037 start
# 11:22:32 [INFO] E0006 batch 0027/0037 done | avg_total=0.00423 avg_data=0.00120 avg_nfe=826 skipped=0 elapsed=1.8m
# 11:22:40 [INFO] E0006 batch 0030/0037 start
# 11:22:44 [INFO] E0006 batch 0030/0037 running | batch_elapsed=3.6s epoch_elapsed=2.0m
# 11:22:44 [INFO] E0006 batch 0030/0037 done | avg_total=0.00416 avg_data=0.00119 avg_nfe=826 skipped=0 elapsed=2.0m
# 11:22:52 [INFO] E0006 batch 0033/0037 start
# 11:22:56 [INFO] E0006 batch 0033/0037 done | avg_total=0.00415 avg_data=0.00119 avg_nfe=826 skipped=0 elapsed=2.2m
# 11:23:04 [INFO] E0006 batch 0036/0037 start
# 11:23:08 [INFO] E0006 batch 0036/0037 done | avg_total=0.00405 avg_data=0.00117 avg_nfe=825 skipped=0 elapsed=2.4m
# 11:23:10 [INFO] E0006 batch 0037/0037 done | avg_total=0.00399 avg_data=0.00116 avg_nfe=812 skipped=0 elapsed=2.4m
# 11:23:22 [INFO] E   6 | T:0.00399 V:0.00035 | RMSE:0.02396 RealRMSE:0.26674 | End:0.03097 RealEnd:0.24674 | NFE:812 | Viol:0.00% | Skip:0 | LR:3.0e-04
# 11:23:22 [INFO] E0007 batch 0001/0037 start
# 11:23:26 [INFO] E0007 batch 0001/0037 done | avg_total=0.00285 avg_data=0.00086 avg_nfe=826 skipped=0 elapsed=0.1m
# 11:23:30 [INFO] E0007 batch 0003/0037 start
# 11:23:34 [INFO] E0007 batch 0003/0037 done | avg_total=0.00301 avg_data=0.00096 avg_nfe=828 skipped=0 elapsed=0.2m
# 11:23:42 [INFO] E0007 batch 0006/0037 start
# 11:23:47 [INFO] E0007 batch 0006/0037 done | avg_total=0.00364 avg_data=0.00108 avg_nfe=826 skipped=0 elapsed=0.4m
# 11:23:52 [INFO] E0007 batch 0008/0037 running | batch_elapsed=1.6s epoch_elapsed=0.5m
# 11:23:55 [INFO] E0007 batch 0009/0037 start
# 11:23:59 [INFO] E0007 batch 0009/0037 done | avg_total=0.00388 avg_data=0.00112 avg_nfe=829 skipped=0 elapsed=0.6m
# 11:24:07 [INFO] E0007 batch 0012/0037 start
# 11:24:11 [INFO] E0007 batch 0012/0037 done | avg_total=0.00370 avg_data=0.00108 avg_nfe=826 skipped=0 elapsed=0.8m
# 11:24:19 [INFO] E0007 batch 0015/0037 start
# 11:24:22 [INFO] E0007 batch 0015/0037 running | batch_elapsed=3.4s epoch_elapsed=1.0m
# 11:24:23 [INFO] E0007 batch 0015/0037 done | avg_total=0.00373 avg_data=0.00109 avg_nfe=829 skipped=0 elapsed=1.0m
# 11:24:31 [INFO] E0007 batch 0018/0037 start
# 11:24:35 [INFO] E0007 batch 0018/0037 done | avg_total=0.00362 avg_data=0.00107 avg_nfe=826 skipped=0 elapsed=1.2m
# 11:24:43 [INFO] E0007 batch 0021/0037 start
# 11:24:47 [INFO] E0007 batch 0021/0037 done | avg_total=0.00352 avg_data=0.00104 avg_nfe=827 skipped=0 elapsed=1.4m
# 11:24:52 [INFO] E0007 batch 0023/0037 running | batch_elapsed=1.5s epoch_elapsed=1.5m
# 11:24:55 [INFO] E0007 batch 0024/0037 start
# 11:24:59 [INFO] E0007 batch 0024/0037 done | avg_total=0.00347 avg_data=0.00103 avg_nfe=829 skipped=0 elapsed=1.6m
# 11:25:07 [INFO] E0007 batch 0027/0037 start
# 11:25:11 [INFO] E0007 batch 0027/0037 done | avg_total=0.00347 avg_data=0.00103 avg_nfe=829 skipped=0 elapsed=1.8m
# 11:25:19 [INFO] E0007 batch 0030/0037 start
# 11:25:22 [INFO] E0007 batch 0030/0037 running | batch_elapsed=3.3s epoch_elapsed=2.0m
# 11:25:23 [INFO] E0007 batch 0030/0037 done | avg_total=0.00350 avg_data=0.00104 avg_nfe=828 skipped=0 elapsed=2.0m
# 11:25:31 [INFO] E0007 batch 0033/0037 start
# 11:25:35 [INFO] E0007 batch 0033/0037 done | avg_total=0.00357 avg_data=0.00106 avg_nfe=828 skipped=0 elapsed=2.2m
# 11:25:42 [INFO] E0007 batch 0036/0037 start
# 11:25:46 [INFO] E0007 batch 0036/0037 done | avg_total=0.00368 avg_data=0.00108 avg_nfe=829 skipped=0 elapsed=2.4m
# 11:25:48 [INFO] E0007 batch 0037/0037 done | avg_total=0.00367 avg_data=0.00108 avg_nfe=816 skipped=0 elapsed=2.4m
# 11:26:00 [INFO] E   7 | T:0.00367 V:0.00036 | RMSE:0.02433 RealRMSE:0.26098 | End:0.03327 RealEnd:0.24160 | NFE:816 | Viol:0.00% | Skip:0 | LR:3.0e-04
# 11:26:00 [INFO] E0008 batch 0001/0037 start
# 11:26:04 [INFO] E0008 batch 0001/0037 done | avg_total=0.00256 avg_data=0.00087 avg_nfe=814 skipped=0 elapsed=0.1m
# 11:26:08 [INFO] E0008 batch 0003/0037 start
# 11:26:11 [INFO] E0008 batch 0003/0037 done | avg_total=0.00347 avg_data=0.00108 avg_nfe=834 skipped=0 elapsed=0.2m
# 11:26:19 [INFO] E0008 batch 0006/0037 start
# 11:26:23 [INFO] E0008 batch 0006/0037 done | avg_total=0.00351 avg_data=0.00103 avg_nfe=830 skipped=0 elapsed=0.4m
# 11:26:30 [INFO] E0008 batch 0008/0037 running | batch_elapsed=3.1s epoch_elapsed=0.5m
# 11:26:31 [INFO] E0008 batch 0009/0037 start
# 11:26:35 [INFO] E0008 batch 0009/0037 done | avg_total=0.00300 avg_data=0.00093 avg_nfe=830 skipped=0 elapsed=0.6m
# 11:26:43 [INFO] E0008 batch 0012/0037 start
# 11:26:47 [INFO] E0008 batch 0012/0037 done | avg_total=0.00298 avg_data=0.00094 avg_nfe=831 skipped=0 elapsed=0.8m
# 11:26:55 [INFO] E0008 batch 0015/0037 start
# 11:26:59 [INFO] E0008 batch 0015/0037 done | avg_total=0.00303 avg_data=0.00096 avg_nfe=831 skipped=0 elapsed=1.0m
# 11:27:00 [INFO] E0008 batch 0016/0037 running | batch_elapsed=0.5s epoch_elapsed=1.0m
# 11:27:08 [INFO] E0008 batch 0018/0037 start
# 11:27:11 [INFO] E0008 batch 0018/0037 done | avg_total=0.00323 avg_data=0.00100 avg_nfe=833 skipped=0 elapsed=1.2m
# 11:27:19 [INFO] E0008 batch 0021/0037 start
# 11:27:23 [INFO] E0008 batch 0021/0037 done | avg_total=0.00331 avg_data=0.00102 avg_nfe=837 skipped=0 elapsed=1.4m
# 11:27:30 [INFO] E0008 batch 0023/0037 running | batch_elapsed=2.2s epoch_elapsed=1.5m
# 11:27:32 [INFO] E0008 batch 0024/0037 start
# 11:27:36 [INFO] E0008 batch 0024/0037 done | avg_total=0.00333 avg_data=0.00103 avg_nfe=840 skipped=0 elapsed=1.6m
# 11:27:44 [INFO] E0008 batch 0027/0037 start
# 11:27:48 [INFO] E0008 batch 0027/0037 done | avg_total=0.00331 avg_data=0.00103 avg_nfe=840 skipped=0 elapsed=1.8m
# 11:27:56 [INFO] E0008 batch 0030/0037 start
# 11:28:00 [INFO] E0008 batch 0030/0037 done | avg_total=0.00336 avg_data=0.00103 avg_nfe=839 skipped=0 elapsed=2.0m
# 11:28:00 [INFO] E0008 batch 0031/0037 running | batch_elapsed=0.2s epoch_elapsed=2.0m
# 11:28:08 [INFO] E0008 batch 0033/0037 start
# 11:28:12 [INFO] E0008 batch 0033/0037 done | avg_total=0.00329 avg_data=0.00102 avg_nfe=840 skipped=0 elapsed=2.2m
# 11:28:20 [INFO] E0008 batch 0036/0037 start
# 11:28:24 [INFO] E0008 batch 0036/0037 done | avg_total=0.00329 avg_data=0.00102 avg_nfe=839 skipped=0 elapsed=2.4m
# 11:28:25 [INFO] E0008 batch 0037/0037 done | avg_total=0.00335 avg_data=0.00103 avg_nfe=826 skipped=0 elapsed=2.4m
# 11:28:37 [INFO] E   8 | T:0.00335 V:0.00037 | RMSE:0.02460 RealRMSE:0.25799 | End:0.03460 RealEnd:0.23892 | NFE:826 | Viol:0.00% | Skip:0 | LR:3.0e-04
# 11:28:37 [INFO] E0009 batch 0001/0037 start
# 11:28:41 [INFO] E0009 batch 0001/0037 done | avg_total=0.00241 avg_data=0.00086 avg_nfe=868 skipped=0 elapsed=0.1m
# 11:28:45 [INFO] E0009 batch 0003/0037 start
# 11:28:49 [INFO] E0009 batch 0003/0037 done | avg_total=0.00297 avg_data=0.00091 avg_nfe=852 skipped=0 elapsed=0.2m
# 11:28:57 [INFO] E0009 batch 0006/0037 start
# 11:29:01 [INFO] E0009 batch 0006/0037 done | avg_total=0.00267 avg_data=0.00087 avg_nfe=846 skipped=0 elapsed=0.4m
# 11:29:07 [INFO] E0009 batch 0008/0037 running | batch_elapsed=1.9s epoch_elapsed=0.5m
# 11:29:09 [INFO] E0009 batch 0009/0037 start
# 11:29:13 [INFO] E0009 batch 0009/0037 done | avg_total=0.00296 avg_data=0.00094 avg_nfe=851 skipped=0 elapsed=0.6m
# 11:29:21 [INFO] E0009 batch 0012/0037 start
# 11:29:25 [INFO] E0009 batch 0012/0037 done | avg_total=0.00317 avg_data=0.00097 avg_nfe=850 skipped=0 elapsed=0.8m
# 11:29:33 [INFO] E0009 batch 0015/0037 start
# 11:29:37 [INFO] E0009 batch 0015/0037 running | batch_elapsed=3.8s epoch_elapsed=1.0m
# 11:29:37 [INFO] E0009 batch 0015/0037 done | avg_total=0.00324 avg_data=0.00099 avg_nfe=854 skipped=0 elapsed=1.0m
# 11:29:45 [INFO] E0009 batch 0018/0037 start
# 11:29:49 [INFO] E0009 batch 0018/0037 done | avg_total=0.00338 avg_data=0.00102 avg_nfe=853 skipped=0 elapsed=1.2m
# 11:29:57 [INFO] E0009 batch 0021/0037 start
# 11:30:01 [INFO] E0009 batch 0021/0037 done | avg_total=0.00322 avg_data=0.00099 avg_nfe=852 skipped=0 elapsed=1.4m
# 11:30:07 [INFO] E0009 batch 0023/0037 running | batch_elapsed=1.5s epoch_elapsed=1.5m
# 11:30:10 [INFO] E0009 batch 0024/0037 start
# 11:30:14 [INFO] E0009 batch 0024/0037 done | avg_total=0.00325 avg_data=0.00099 avg_nfe=855 skipped=0 elapsed=1.6m
# 11:30:22 [INFO] E0009 batch 0027/0037 start
# 11:30:26 [INFO] E0009 batch 0027/0037 done | avg_total=0.00325 avg_data=0.00099 avg_nfe=852 skipped=0 elapsed=1.8m
# 11:30:34 [INFO] E0009 batch 0030/0037 start
# 11:30:37 [INFO] E0009 batch 0030/0037 running | batch_elapsed=3.4s epoch_elapsed=2.0m
# 11:30:38 [INFO] E0009 batch 0030/0037 done | avg_total=0.00324 avg_data=0.00099 avg_nfe=852 skipped=0 elapsed=2.0m
# 11:30:46 [INFO] E0009 batch 0033/0037 start
# 11:30:50 [INFO] E0009 batch 0033/0037 done | avg_total=0.00333 avg_data=0.00101 avg_nfe=853 skipped=0 elapsed=2.2m
# 11:30:58 [INFO] E0009 batch 0036/0037 start
# 11:31:02 [INFO] E0009 batch 0036/0037 done | avg_total=0.00334 avg_data=0.00101 avg_nfe=852 skipped=0 elapsed=2.4m
# 11:31:04 [INFO] E0009 batch 0037/0037 done | avg_total=0.00333 avg_data=0.00101 avg_nfe=838 skipped=0 elapsed=2.4m
# 11:31:16 [INFO] E   9 | T:0.00333 V:0.00039 | RMSE:0.02506 RealRMSE:0.25398 | End:0.03640 RealEnd:0.23530 | NFE:838 | Viol:0.00% | Skip:0 | LR:2.9e-04
# 11:31:16 [INFO] E0010 batch 0001/0037 start
# 11:31:19 [INFO] E0010 batch 0001/0037 done | avg_total=0.00549 avg_data=0.00129 avg_nfe=856 skipped=0 elapsed=0.1m
# 11:31:23 [INFO] E0010 batch 0003/0037 start
# 11:31:27 [INFO] E0010 batch 0003/0037 done | avg_total=0.00837 avg_data=0.00190 avg_nfe=858 skipped=0 elapsed=0.2m
# 11:31:35 [INFO] E0010 batch 0006/0037 start
# 11:31:39 [INFO] E0010 batch 0006/0037 done | avg_total=0.00595 avg_data=0.00148 avg_nfe=861 skipped=0 elapsed=0.4m
# 11:31:46 [INFO] E0010 batch 0008/0037 running | batch_elapsed=3.0s epoch_elapsed=0.5m
# 11:31:47 [INFO] E0010 batch 0009/0037 start
# 11:31:51 [INFO] E0010 batch 0009/0037 done | avg_total=0.00457 avg_data=0.00120 avg_nfe=855 skipped=0 elapsed=0.6m
# 11:31:59 [INFO] E0010 batch 0012/0037 start
# 11:32:03 [INFO] E0010 batch 0012/0037 done | avg_total=0.00446 avg_data=0.00119 avg_nfe=854 skipped=0 elapsed=0.8m
# 11:32:11 [INFO] E0010 batch 0015/0037 start
# 11:32:15 [INFO] E0010 batch 0015/0037 done | avg_total=0.00436 avg_data=0.00118 avg_nfe=857 skipped=0 elapsed=1.0m
# 11:32:16 [INFO] E0010 batch 0016/0037 running | batch_elapsed=0.2s epoch_elapsed=1.0m
# 11:32:24 [INFO] E0010 batch 0018/0037 start
# 11:32:28 [INFO] E0010 batch 0018/0037 done | avg_total=0.00421 avg_data=0.00115 avg_nfe=857 skipped=0 elapsed=1.2m
# 11:32:36 [INFO] E0010 batch 0021/0037 start
# 11:32:40 [INFO] E0010 batch 0021/0037 done | avg_total=0.00411 avg_data=0.00114 avg_nfe=858 skipped=0 elapsed=1.4m
# 11:32:46 [INFO] E0010 batch 0023/0037 running | batch_elapsed=1.6s epoch_elapsed=1.5m
# 11:32:48 [INFO] E0010 batch 0024/0037 start
# 11:32:52 [INFO] E0010 batch 0024/0037 done | avg_total=0.00417 avg_data=0.00115 avg_nfe=861 skipped=0 elapsed=1.6m
# 11:33:00 [INFO] E0010 batch 0027/0037 start
# 11:33:05 [INFO] E0010 batch 0027/0037 done | avg_total=0.00415 avg_data=0.00115 avg_nfe=862 skipped=0 elapsed=1.8m
# 11:33:13 [INFO] E0010 batch 0030/0037 start
# 11:33:16 [INFO] E0010 batch 0030/0037 running | batch_elapsed=2.9s epoch_elapsed=2.0m
# 11:33:17 [INFO] E0010 batch 0030/0037 done | avg_total=0.00415 avg_data=0.00116 avg_nfe=863 skipped=0 elapsed=2.0m
# 11:33:25 [INFO] E0010 batch 0033/0037 start
# 11:33:29 [INFO] E0010 batch 0033/0037 done | avg_total=0.00398 avg_data=0.00112 avg_nfe=858 skipped=0 elapsed=2.2m
# 11:33:37 [INFO] E0010 batch 0036/0037 start
# 11:33:41 [INFO] E0010 batch 0036/0037 done | avg_total=0.00386 avg_data=0.00110 avg_nfe=859 skipped=0 elapsed=2.4m
# 11:33:42 [INFO] E0010 batch 0037/0037 done | avg_total=0.00381 avg_data=0.00109 avg_nfe=845 skipped=0 elapsed=2.4m
# 11:33:55 [INFO] E  10 | T:0.00381 V:0.00041 | RMSE:0.02576 RealRMSE:0.24896 | End:0.03870 RealEnd:0.23071 | NFE:845 | Viol:0.00% | Skip:0 | LR:2.9e-04
# 11:33:55 [INFO] E0011 batch 0001/0037 start
# 11:33:59 [INFO] E0011 batch 0001/0037 done | avg_total=0.00282 avg_data=0.00097 avg_nfe=862 skipped=0 elapsed=0.1m
# 11:34:02 [INFO] E0011 batch 0003/0037 start
# 11:34:06 [INFO] E0011 batch 0003/0037 done | avg_total=0.00283 avg_data=0.00092 avg_nfe=850 skipped=0 elapsed=0.2m
# 11:34:14 [INFO] E0011 batch 0006/0037 start
# 11:34:19 [INFO] E0011 batch 0006/0037 done | avg_total=0.00339 avg_data=0.00102 avg_nfe=865 skipped=0 elapsed=0.4m
# 11:34:25 [INFO] E0011 batch 0008/0037 running | batch_elapsed=2.2s epoch_elapsed=0.5m
# 11:34:27 [INFO] E0011 batch 0009/0037 start
# 11:34:31 [INFO] E0011 batch 0009/0037 done | avg_total=0.00352 avg_data=0.00103 avg_nfe=871 skipped=0 elapsed=0.6m
# 11:34:39 [INFO] E0011 batch 0012/0037 start
# 11:34:43 [INFO] E0011 batch 0012/0037 done | avg_total=0.00362 avg_data=0.00105 avg_nfe=870 skipped=0 elapsed=0.8m
# 11:34:51 [INFO] E0011 batch 0015/0037 start
# 11:34:55 [INFO] E0011 batch 0015/0037 done | avg_total=0.00379 avg_data=0.00108 avg_nfe=869 skipped=0 elapsed=1.0m
# 11:34:55 [INFO] E0011 batch 0016/0037 running | batch_elapsed=0.1s epoch_elapsed=1.0m
# 11:35:03 [INFO] E0011 batch 0018/0037 start
# 11:35:07 [INFO] E0011 batch 0018/0037 done | avg_total=0.00390 avg_data=0.00110 avg_nfe=869 skipped=0 elapsed=1.2m
# 11:35:15 [INFO] E0011 batch 0021/0037 start
# 11:35:19 [INFO] E0011 batch 0021/0037 done | avg_total=0.00394 avg_data=0.00111 avg_nfe=869 skipped=0 elapsed=1.4m
# 11:35:25 [INFO] E0011 batch 0023/0037 running | batch_elapsed=1.6s epoch_elapsed=1.5m
# 11:35:27 [INFO] E0011 batch 0024/0037 start
# 11:35:31 [INFO] E0011 batch 0024/0037 done | avg_total=0.00395 avg_data=0.00111 avg_nfe=870 skipped=0 elapsed=1.6m
# 11:35:39 [INFO] E0011 batch 0027/0037 start
# 11:35:43 [INFO] E0011 batch 0027/0037 done | avg_total=0.00391 avg_data=0.00110 avg_nfe=868 skipped=0 elapsed=1.8m
# 11:35:51 [INFO] E0011 batch 0030/0037 start
# 11:35:55 [INFO] E0011 batch 0030/0037 running | batch_elapsed=3.7s epoch_elapsed=2.0m
# 11:35:55 [INFO] E0011 batch 0030/0037 done | avg_total=0.00398 avg_data=0.00112 avg_nfe=869 skipped=0 elapsed=2.0m
# 11:36:03 [INFO] E0011 batch 0033/0037 start
# 11:36:07 [INFO] E0011 batch 0033/0037 done | avg_total=0.00388 avg_data=0.00111 avg_nfe=868 skipped=0 elapsed=2.2m
# 11:36:15 [INFO] E0011 batch 0036/0037 start
# 11:36:19 [INFO] E0011 batch 0036/0037 done | avg_total=0.00391 avg_data=0.00111 avg_nfe=868 skipped=0 elapsed=2.4m
# 11:36:21 [INFO] E0011 batch 0037/0037 done | avg_total=0.00389 avg_data=0.00111 avg_nfe=854 skipped=0 elapsed=2.4m
# 11:36:33 [INFO] E  11 | T:0.00389 V:0.00043 | RMSE:0.02623 RealRMSE:0.24612 | End:0.04004 RealEnd:0.22810 | NFE:854 | Viol:0.00% | Skip:0 | LR:2.9e-04
# 11:36:33 [INFO] E0012 batch 0001/0037 start
# 11:36:37 [INFO] E0012 batch 0001/0037 done | avg_total=0.00302 avg_data=0.00091 avg_nfe=874 skipped=0 elapsed=0.1m
# 11:36:41 [INFO] E0012 batch 0003/0037 start
# 11:36:45 [INFO] E0012 batch 0003/0037 done | avg_total=0.00346 avg_data=0.00101 avg_nfe=878 skipped=0 elapsed=0.2m
# 11:36:53 [INFO] E0012 batch 0006/0037 start
# 11:36:58 [INFO] E0012 batch 0006/0037 done | avg_total=0.00379 avg_data=0.00108 avg_nfe=879 skipped=0 elapsed=0.4m
# 11:37:03 [INFO] E0012 batch 0008/0037 running | batch_elapsed=1.8s epoch_elapsed=0.5m
# 11:37:05 [INFO] E0012 batch 0009/0037 start
# 11:37:10 [INFO] E0012 batch 0009/0037 done | avg_total=0.00329 avg_data=0.00097 avg_nfe=871 skipped=0 elapsed=0.6m
# 11:37:18 [INFO] E0012 batch 0012/0037 start
# 11:37:22 [INFO] E0012 batch 0012/0037 done | avg_total=0.00330 avg_data=0.00099 avg_nfe=874 skipped=0 elapsed=0.8m
# 11:37:30 [INFO] E0012 batch 0015/0037 start
# 11:37:33 [INFO] E0012 batch 0015/0037 running | batch_elapsed=3.5s epoch_elapsed=1.0m
# 11:37:34 [INFO] E0012 batch 0015/0037 done | avg_total=0.00366 avg_data=0.00107 avg_nfe=878 skipped=0 elapsed=1.0m
# 11:37:42 [INFO] E0012 batch 0018/0037 start
# 11:37:46 [INFO] E0012 batch 0018/0037 done | avg_total=0.00369 avg_data=0.00107 avg_nfe=881 skipped=0 elapsed=1.2m
# ...
# 15:39:54 [INFO] E0167 batch 0003/0003 start
# 15:39:55 [INFO] E0167 batch 0003/0003 done | avg_total=0.09611 avg_data=0.01705 avg_nfe=747 skipped=0 elapsed=0.1m
# 15:39:56 [INFO] E 167 | T:0.09611 V:0.02047 | RMSE:0.21822 RealRMSE:0.21822 | End:0.20067 RealEnd:0.20067 | NFE:747 | Viol:0.00% | Skip:0 | LR:2.2e-04
# 15:39:56 [INFO] E0168 batch 0001/0003 start
# 15:40:00 [INFO] E0168 batch 0001/0003 done | avg_total=0.08954 avg_data=0.01365 avg_nfe=1006 skipped=0 elapsed=0.1m
# 15:40:04 [INFO] E0168 batch 0003/0003 start
# 15:40:05 [INFO] E0168 batch 0003/0003 done | avg_total=0.11257 avg_data=0.01978 avg_nfe=767 skipped=0 elapsed=0.1m
# 15:40:06 [INFO] E 168 | T:0.11257 V:0.02032 | RMSE:0.21730 RealRMSE:0.21730 | End:0.19969 RealEnd:0.19969 | NFE:767 | Viol:0.00% | Skip:0 | LR:2.2e-04
# 15:40:06 [INFO] E0169 batch 0001/0003 start
# 15:40:10 [INFO] E0169 batch 0001/0003 done | avg_total=0.07870 avg_data=0.01425 avg_nfe=1006 skipped=0 elapsed=0.1m
# 15:40:13 [INFO] E0169 batch 0003/0003 start
# 15:40:15 [INFO] E0169 batch 0003/0003 done | avg_total=0.10173 avg_data=0.01805 avg_nfe=759 skipped=0 elapsed=0.1m
# 15:40:15 [INFO] E 169 | T:0.10173 V:0.02017 | RMSE:0.21638 RealRMSE:0.21638 | End:0.19871 RealEnd:0.19871 | NFE:759 | Viol:0.00% | Skip:0 | LR:2.2e-04
# 15:40:15 [INFO] E0170 batch 0001/0003 start
# 15:40:19 [INFO] E0170 batch 0001/0003 done | avg_total=0.10514 avg_data=0.01955 avg_nfe=958 skipped=0 elapsed=0.1m
# 15:40:23 [INFO] E0170 batch 0003/0003 start
# 15:40:24 [INFO] E0170 batch 0003/0003 done | avg_total=0.09450 avg_data=0.01742 avg_nfe=745 skipped=0 elapsed=0.1m
# 15:40:25 [INFO] E 170 | T:0.09450 V:0.02002 | RMSE:0.21547 RealRMSE:0.21547 | End:0.19772 RealEnd:0.19772 | NFE:745 | Viol:0.00% | Skip:0 | LR:2.2e-04
# 15:40:25 [INFO] E0171 batch 0001/0003 start
# 15:40:28 [INFO] E0171 batch 0001/0003 done | avg_total=0.10310 avg_data=0.01804 avg_nfe=928 skipped=0 elapsed=0.1m
# 15:40:32 [INFO] E0171 batch 0003/0003 start
# 15:40:33 [INFO] E0171 batch 0003/0003 done | avg_total=0.10801 avg_data=0.01925 avg_nfe=735 skipped=0 elapsed=0.1m
# 15:40:34 [INFO] E 171 | T:0.10801 V:0.01988 | RMSE:0.21460 RealRMSE:0.21460 | End:0.19679 RealEnd:0.19679 | NFE:735 | Viol:0.00% | Skip:0 | LR:2.2e-04
# 15:40:34 [INFO] E0172 batch 0001/0003 start
# 15:40:38 [INFO] E0172 batch 0001/0003 done | avg_total=0.09638 avg_data=0.01680 avg_nfe=1012 skipped=0 elapsed=0.1m
# 15:40:42 [INFO] E0172 batch 0003/0003 start
# 15:40:43 [INFO] E0172 batch 0003/0003 done | avg_total=0.11225 avg_data=0.02069 avg_nfe=775 skipped=0 elapsed=0.2m
# 15:40:44 [INFO] E 172 | T:0.11225 V:0.01973 | RMSE:0.21372 RealRMSE:0.21372 | End:0.19582 RealEnd:0.19582 | NFE:775 | Viol:0.00% | Skip:0 | LR:2.1e-04
# 15:40:44 [INFO] E0173 batch 0001/0003 start
# 15:40:48 [INFO] E0173 batch 0001/0003 done | avg_total=0.07864 avg_data=0.01394 avg_nfe=1030 skipped=0 elapsed=0.1m
# 15:40:52 [INFO] E0173 batch 0003/0003 start
# 15:40:53 [INFO] E0173 batch 0003/0003 done | avg_total=0.08717 avg_data=0.01619 avg_nfe=777 skipped=0 elapsed=0.1m
# 15:40:54 [INFO] E 173 | T:0.08717 V:0.01958 | RMSE:0.21282 RealRMSE:0.21282 | End:0.19484 RealEnd:0.19484 | NFE:777 | Viol:0.00% | Skip:0 | LR:2.1e-04
# 15:40:54 [INFO] E0174 batch 0001/0003 start
# 15:40:57 [INFO] E0174 batch 0001/0003 done | avg_total=0.12713 avg_data=0.02436 avg_nfe=982 skipped=0 elapsed=0.1m
# 15:41:01 [INFO] E0174 batch 0003/0003 start
# 15:41:02 [INFO] E0174 batch 0003/0003 done | avg_total=0.11007 avg_data=0.02082 avg_nfe=751 skipped=0 elapsed=0.1m
# 15:41:03 [INFO] E 174 | T:0.11007 V:0.01944 | RMSE:0.21197 RealRMSE:0.21197 | End:0.19390 RealEnd:0.19390 | NFE:751 | Viol:0.00% | Skip:0 | LR:2.1e-04
# 15:41:03 [INFO] E0175 batch 0001/0003 start
# 15:41:07 [INFO] E0175 batch 0001/0003 done | avg_total=0.11517 avg_data=0.02303 avg_nfe=994 skipped=0 elapsed=0.1m
# 15:41:11 [INFO] E0175 batch 0003/0003 start
# 15:41:12 [INFO] E0175 batch 0003/0003 done | avg_total=0.09623 avg_data=0.01827 avg_nfe=757 skipped=0 elapsed=0.1m
# 15:41:13 [INFO] E 175 | T:0.09623 V:0.01931 | RMSE:0.21117 RealRMSE:0.21117 | End:0.19302 RealEnd:0.19302 | NFE:757 | Viol:0.00% | Skip:0 | LR:2.1e-04
# 15:41:13 [INFO] E0176 batch 0001/0003 start
# 15:41:16 [INFO] E0176 batch 0001/0003 done | avg_total=0.10379 avg_data=0.01970 avg_nfe=952 skipped=0 elapsed=0.1m
# 15:41:20 [INFO] E0176 batch 0003/0003 start
# 15:41:21 [INFO] E0176 batch 0003/0003 done | avg_total=0.08321 avg_data=0.01434 avg_nfe=743 skipped=0 elapsed=0.1m
# 15:41:22 [INFO] E 176 | T:0.08321 V:0.01919 | RMSE:0.21041 RealRMSE:0.21041 | End:0.19226 RealEnd:0.19226 | NFE:743 | Viol:0.00% | Skip:0 | LR:2.1e-04
# 15:41:22 [INFO] E0177 batch 0001/0003 start
# 15:41:26 [INFO] E0177 batch 0001/0003 done | avg_total=0.07205 avg_data=0.01263 avg_nfe=976 skipped=0 elapsed=0.1m
# 15:41:30 [INFO] E0177 batch 0003/0003 start
# 15:41:31 [INFO] E0177 batch 0003/0003 done | avg_total=0.09702 avg_data=0.01881 avg_nfe=755 skipped=0 elapsed=0.1m
# 15:41:32 [INFO] E 177 | T:0.09702 V:0.01907 | RMSE:0.20968 RealRMSE:0.20968 | End:0.19154 RealEnd:0.19154 | NFE:755 | Viol:0.00% | Skip:0 | LR:2.0e-04
# 15:41:32 [INFO] E0178 batch 0001/0003 start
# 15:41:35 [INFO] E0178 batch 0001/0003 done | avg_total=0.10235 avg_data=0.01802 avg_nfe=982 skipped=0 elapsed=0.1m
# 15:41:39 [INFO] E0178 batch 0003/0003 start
# 15:41:41 [INFO] E0178 batch 0003/0003 done | avg_total=0.09273 avg_data=0.01596 avg_nfe=763 skipped=0 elapsed=0.1m
# 15:41:41 [INFO] E 178 | T:0.09273 V:0.01895 | RMSE:0.20893 RealRMSE:0.20893 | End:0.19080 RealEnd:0.19080 | NFE:763 | Viol:0.00% | Skip:0 | LR:2.0e-04
# 15:41:41 [INFO] E0179 batch 0001/0003 start
# 15:41:45 [INFO] E0179 batch 0001/0003 done | avg_total=0.10853 avg_data=0.02171 avg_nfe=970 skipped=0 elapsed=0.1m
# 15:41:49 [INFO] E0179 batch 0003/0003 start
# 15:41:50 [INFO] E0179 batch 0003/0003 done | avg_total=0.10806 avg_data=0.02043 avg_nfe=777 skipped=0 elapsed=0.1m
# 15:41:51 [INFO] E 179 | T:0.10806 V:0.01882 | RMSE:0.20816 RealRMSE:0.20816 | End:0.19003 RealEnd:0.19003 | NFE:777 | Viol:0.00% | Skip:0 | LR:2.0e-04
# 15:41:51 [INFO] E0180 batch 0001/0003 start
# 15:41:55 [INFO] E0180 batch 0001/0003 done | avg_total=0.12453 avg_data=0.02387 avg_nfe=994 skipped=0 elapsed=0.1m
# 15:41:59 [INFO] E0180 batch 0003/0003 start
# 15:42:00 [INFO] E0180 batch 0003/0003 done | avg_total=0.11334 avg_data=0.02232 avg_nfe=761 skipped=0 elapsed=0.1m
# 15:42:01 [INFO] E 180 | T:0.11334 V:0.01869 | RMSE:0.20735 RealRMSE:0.20735 | End:0.18922 RealEnd:0.18922 | NFE:761 | Viol:0.00% | Skip:0 | LR:2.0e-04
# 15:42:01 [INFO] Done in 25.0m | Best val_real_rmse: 0.207348
# 15:42:01 [INFO] Pipeline done in 25.0m
# Snapshot: /kaggle/working/project_4_3_final_artifacts_snapshot.zip
# [time] before 06_evaluate_export: elapsed=4.59h
#
# ================================================================================
# RUN eval_evaluate_comprehensive.py
# CMD: /usr/bin/python3 /kaggle/working/project43_latent_stage2_real_only/evaluate_comprehensive.py
# CWD: /kaggle/working/project43_latent_stage2_real_only
# ================================================================================
# Traceback (most recent call last):
#   File "/kaggle/working/project43_latent_stage2_real_only/evaluate_comprehensive.py", line 34, in <module>
#     ckpt = torch.load(ckpt_path, map_location='cpu', weights_only=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1500, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 768, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 749, in __init__
#     super().__init__(open(name, mode))  # noqa: SIM115
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/project43_latent_stage2_real_only/models/stage2_fixed_best.pt'
#
# ================================================================================
# RUN eval_validate_calphad.py
# CMD: /usr/bin/python3 /kaggle/working/project43_latent_stage2_real_only/validate_calphad.py
# CWD: /kaggle/working/project43_latent_stage2_real_only
# ================================================================================
# CALPHAD not available: No module named 'pycalphad'
# Skipping CALPHAD validation (pycalphad not available)
#
# ================================================================================
# RUN eval_analysis.py
# CMD: /usr/bin/python3 /kaggle/working/project43_latent_stage2_real_only/analysis.py
# CWD: /kaggle/working/project43_latent_stage2_real_only
# ================================================================================
# ======================================================================
# DATASET ANALYSIS
# ======================================================================
# Total data points: 125
# Unique studies: 25
#
# Study                     Points    Mn     C    Al     T range (C)     Method         Quality
# ----------------------------------------------------------------------------------------------------
# aliabad_2026                   2   6.0  0.40   2.0    680-   680    EBSD,XRD   text_reported
# arlazarov_2012                 5   5.0  0.10   0.0    600-   700         XRD digitized_figure
# cai_2016                       4  10.0  0.30   2.0    625-   700         XRD digitized_figure
# demoor_2011                    5   7.1  0.11   0.0    600-   600         XRD digitized_figure
# demoor_2015                    6   7.0  0.10   0.0    620-   620         XRD digitized_figure
# frontiers_2020                 2   8.0  0.20   3.0    680-   680    EBSD,XRD   text_reported
# gibbs_2011                     5   7.1  0.10   0.0    575-   675  XRD,neutron_diffraction           table
# han_2014                       6   9.0  0.05   0.0    600-   725         XRD digitized_figure
# hausman_2017                   4   6.0  0.30   0.0    575-   650         XRD digitized_figure
# hu_luo_2017                    4   7.0  0.10   0.5    600-   675         XRD digitized_figure
# lee_decooman_2014              6   5.8  0.12   2.0    625-   750         XRD digitized_figure
# lpbf_2021                      3   3.9  0.23   2.0     25-   750         XRD   text_reported
# luo_2011                       7   5.0  0.20   0.0    650-   650         XRD digitized_figure,text_reported
# ma_2019                        6   8.0  0.20   2.0    625-   750         XRD digitized_figure
# miller_2013                    5   5.8  0.10   0.0    600-   700         XRD digitized_figure
# nakada_2014                    7   6.0  0.00   0.0    500-   675         XRD digitized_figure
# pmc11053108_2024               7   4.7  0.16   1.6    640-  1000         XRD   text_reported
# pmc11173901_2024               3   9.4  0.20   4.3    750-   850         XRD digitized_figure
# pmc6266817_2018                6   5.0  0.12   1.0    600-   750         XRD digitized_figure,text_reported
# pmc6266817_2018_HR             4   5.0  0.12   1.0    600-   690         XRD digitized_figure,text_reported
# shi_2010                       5   5.0  0.20   0.0    620-   680         XRD digitized_figure
# suh_2017                       5   6.0  0.10   3.0    700-   800         XRD digitized_figure
# sun_2018                       8  12.0  0.05   0.0    575-   675         XRD digitized_figure
# yan_2022                       3   6.0  0.15   1.5    650-   710        EBSD   text_reported
# zhao_2014                      7   7.9  0.07   0.1    580-   700         XRD digitized_figure
#
# Measurement methods:
#   XRD: 116 points (92.8%)
#   EBSD: 5 points (4.0%)
#   neutron_diffraction: 4 points (3.2%)
# Data quality flags:
#   digitized_figure: 96 points (76.8%)
#   text_reported: 24 points (19.2%)
#   table: 5 points (4.0%)
#
# Composition ranges:
#   Mn: 3.93 - 12.00
#   C: 0.00 - 0.40
#   Al: 0.00 - 4.30
#   Si: 0.00 - 1.00
#   Mo: 0.00 - 0.20
#   Nb: 0.00 - 0.05
#   T_celsius: 25 - 1000
#   t_seconds: 0 - 604800 (168 hours)
#   f_RA: 0.000 - 0.647
#
# MEASUREMENT METHOD DISCREPANCY (same condition, different methods):
#   aliabad @ 680C, 3600s:
#     XRD: 34.0% (study: aliabad_2026)
#     EBSD: 38.0% (study: aliabad_2026)
#   frontiers @ 680C, 3600s:
#     XRD: 64.7% (study: frontiers_2020)
#     EBSD: 47.2% (study: frontiers_2020)
#
# ======================================================================
# TRAINING DYNAMICS
# ======================================================================
# Stage 1: 0 epochs
#
# Stage 2 Fixed (Run 06): 0 epochs
#
# Stage 2 Run 07 (60 epochs): 0 epochs
#
# ======================================================================
# MODEL COMPARISON (Run 06 vs Run 07)
# ======================================================================
#
# KEY OBSERVATION:
#   Run 06 has better TEST metrics (0.312 vs 0.328)
#   Run 07 has better VAL metrics (0.211 vs 0.212)
#   This is expected with 16-curve validation sets - noise dominates
#   Run 06 remains the best model for deployment
#
# ======================================================================
# JMAK BASELINE ANALYSIS
# ======================================================================
# Fitting f(t) = f_max * (1 - exp(-k * t^n)) per isothermal curve
#
# Found 4 isothermal curves with 3+ time points
#
#   luo_2011 @ 650C: n=0.7, k=9.12e-04, RMSE=0.0285 (7 points)
#   demoor_2011 @ 600C: n=0.4, k=1.83e-02, RMSE=0.0119 (5 points)
#   sun_2018 @ 625C: n=0.6, k=4.09e-03, RMSE=0.0082 (4 points)
#   demoor_2015 @ 620C: n=0.4, k=1.83e-02, RMSE=0.0153 (6 points)
#
# NOTE: JMAK fits well within a single study's isothermal curve.
# But JMAK parameters are NOT transferable across compositions.
# The Neural ODE's value is cross-composition generalization.
#
# Report saved to: /kaggle/working/project43_latent_stage2_real_only/analysis_results/full_analysis_report.txt
#
# ================================================================================
# RUN eval_ablation_study.py
# CMD: /usr/bin/python3 /kaggle/working/project43_latent_stage2_real_only/ablation_study.py
# CWD: /kaggle/working/project43_latent_stage2_real_only
# ================================================================================
# Traceback (most recent call last):
#   File "/kaggle/working/project43_latent_stage2_real_only/ablation_study.py", line 32, in <module>
#     ckpt = torch.load(ckpt_path, map_location='cpu', weights_only=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1500, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 768, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 749, in __init__
#     super().__init__(open(name, mode))  # noqa: SIM115
#                      ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/project43_latent_stage2_real_only/models/stage2_extended_best.pt'
# Snapshot: /kaggle/working/project_4_3_final_artifacts_snapshot.zip
# Snapshot: /kaggle/working/project_4_3_final_artifacts_snapshot.zip
#
# ================================================================================
# PROJECT 4.3 SINGLE-CELL RUN FINISHED
# {
#   "started_utc": "2026-05-06T11:06:26.700555+00:00",
#   "finished_utc": "2026-05-06T15:42:14.953042+00:00",
#   "elapsed_hours": 4.5967,
#   "artifact_root": "/kaggle/working/project_4_3_final_artifacts",
#   "snapshot_zip": "/kaggle/working/project_4_3_final_artifacts_snapshot.zip",
#   "done_stages": [
#     "00_setup_extract",
#     "01_baselines_ml_basic_nn",
#     "02_latent_stage1_generate_full",
#     "03_latent_stage1_train_90ep",
#     "04_latent_stage2_generate_real_only",
#     "05_latent_stage2_train_180ep_real_only",
#     "06_evaluate_export"
#   ],
#   "failed_stages": [],
#   "continue_on_stage_error": true
# }
# ================================================================================
